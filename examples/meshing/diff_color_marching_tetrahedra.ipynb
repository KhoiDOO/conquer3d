# %%
import sys
import os
if os.path.abspath('..') not in sys.path:
    sys.path.append(os.path.abspath('..'))

from matplotlib import pyplot as plt
import conquer3d as c3d
import open3d as o3d
import matplotlib.cm as cm
from conquer3d.ops.delaunay_triangulation import tetrahedralize, get_edges
from conquer3d.ops.marching_tetrahedra import marching_tetrahedra


import torch
import tqdm
import numpy as np
import kaolin as kal
import render
import open3d as o3d
import matplotlib.cm as cm
import util
import nvdiffrast.torch as dr
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
iter = 1000
batch = 8
train_res = [2048, 2048]
learning_rate = 0.01
device = 'cuda'

glctx = dr.RasterizeCudaContext(device=device)

# %%
mesh = o3d.io.read_triangle_mesh(o3d.data.BunnyMesh().path)

print("# vertices:", len(mesh.vertices))
print("# triangles:", len(mesh.triangles))

print(type(mesh))
# Out:
# # vertices: 35947
# # triangles: 69451
# <class 'open3d.cuda.pybind.geometry.TriangleMesh'>

# %%
# Make front face towards +Z
R = mesh.get_rotation_matrix_from_xyz((0, np.pi, 0))
mesh.rotate(R, center=(0, 0, 0))
# Apply rainbow coloring to the mesh based on Y-axis height
y_vals = np.asarray(mesh.vertices)[:, 1]
y_norm = (y_vals - y_vals.min()) / (y_vals.max() - y_vals.min() + 1e-8)
colors = cm.rainbow(y_norm)[:, :3]
mesh.vertex_colors = o3d.utility.Vector3dVector(colors)

# %%
vertices = np.asarray(mesh.vertices).astype(np.float32)
triangles = np.asarray(mesh.triangles).astype(np.int64)

target_colors = np.asarray(mesh.vertex_colors).astype(np.float32)

print(f"vertices: {vertices.shape}, triangles: {triangles.shape}")
print(f"vertices: {vertices.dtype}, triangles: {triangles.dtype}")
print(f"vertices min: {vertices.min()},\nvertices max: {vertices.max()}")
# Out:
# vertices: (35947, 3), triangles: (69451, 3)
# vertices: float32, triangles: int64
# vertices min: -0.06100910156965256,
# vertices max: 0.1873210072517395

# %%
vertices = torch.from_numpy(vertices).float()
triangles = torch.from_numpy(triangles).long()
vertices_colors = torch.from_numpy(target_colors).float()

vmin, vmax = vertices.min(dim=0)[0], vertices.max(dim=0)[0]
scale = 1.8 / torch.max(vmax - vmin).item()

vertices = vertices - (vmax + vmin) / 2
vertices = vertices * scale

print(f"vertices min: {vertices.min()}, \nvertices max: {vertices.max()}")
print(f"vertices: {vertices.shape}, triangles: {triangles.shape}")
# Out:
# vertices min: -0.9000000357627869,
# vertices max: 0.9000000357627869
# vertices: torch.Size([35947, 3]), triangles: torch.Size([69451, 3])

# %%
vertices = vertices.to(device)
triangles = triangles.to(device)
vertices_colors = vertices_colors.to(device)

gt_mesh = kal.rep.SurfaceMesh(vertices=vertices, faces=triangles, vertex_colors=vertices_colors)

# %%
num_sampling_points = 100000

pc, _ = kal.ops.mesh.sample_points(gt_mesh.vertices.unsqueeze(0), gt_mesh.faces, num_sampling_points)
pc = pc.squeeze(0)

print(f"pc: {pc.shape}, {pc.dtype}")
# Out:
# pc: torch.Size([100000, 3]), torch.float32

# %%
def create_random_points_ball(n_points, radius=1.0):
    points = torch.randn(n_points, 3, device=device)
    radii = torch.rand(n_points, 1, device=device) ** (1/3) * radius
    points = (points / points.norm(dim=-1, keepdim=True)) * radii
    return points

grid_vertices = create_random_points_ball(100000, 1.2)
tetras = tetrahedralize(grid_vertices)

print(f"grid_vertices: {grid_vertices.shape}, tetras: {tetras.shape}")
print(f"grid_vertices: {grid_vertices.dtype}, tetras: {tetras.dtype}")
print(f"grid_vertices min: {grid_vertices.min()}, grid_vertices max: {grid_vertices.max()}")
# Out:
# grid_vertices: torch.Size([100000, 3]), tetras: torch.Size([669113, 4])
# grid_vertices: torch.float32, tetras: torch.int64
# grid_vertices min: -1.1993756294250488, grid_vertices max: 1.1979061365127563

# %%
sdf = torch.rand_like(grid_vertices[:,0]) - 0.1
sdf = torch.nn.Parameter(sdf.clone().detach(), requires_grad=True)
grid_vertices = torch.nn.Parameter(grid_vertices.clone().detach(), requires_grad=True)
grid_colors = torch.nn.Parameter(torch.rand(grid_vertices.shape[0], 3, device=device), requires_grad=True)

print(f"sdf: {sdf.shape}, {sdf.dtype}")
print(f"sdf min: {sdf.min()}, sdf max: {sdf.max()}")
print(f"sdf requires_grad: {sdf.requires_grad}")
# Out:
# sdf: torch.Size([100000]), torch.float32
# sdf min: -0.09998935461044312, sdf max: 0.8999947905540466
# sdf requires_grad: True

# %%
with torch.no_grad():
    mc_vertices, mc_faces = marching_tetrahedra(grid_vertices, tetras, sdf)

print(f"vertices: {mc_vertices.shape}, faces: {mc_faces.shape}")
if mc_vertices.shape[0] > 0:
    init_mesh = kal.rep.SurfaceMesh(vertices=mc_vertices, faces=mc_faces)
    
    camera = render.get_rotate_camera(5)
    f, ax = plt.subplots(1, 2, figsize=(10, 5))
    output = render.render_mesh(glctx, init_mesh, camera, [512, 512], return_types=['normals'])
    ax[0].imshow(((output['normals'][0] + 1) / 2.).cpu().detach().numpy())
    ax[0].set_title("Initialization")
    ax[0].axis('off')
    
    output = render.render_mesh(glctx, gt_mesh, camera, [512, 512], return_types=['normals'])
    ax[1].imshow(((output['normals'][0] + 1) / 2.).cpu().detach().numpy())
    ax[1].set_title("Ground Truth")
    ax[1].axis('off')
    plt.show()
# Out:
# vertices: torch.Size([139959, 3]), faces: torch.Size([264574, 3])

# %%
def lr_schedule(iter):
    return max(0.0, 10 ** (-(iter) * 0.0002)) # Exponential falloff from [1.0, 0.1] over 5k epochs.    
optimizer = torch.optim.Adam([{'params': sdf}, {'params': grid_vertices, 'lr': learning_rate}, {'params': grid_colors}], lr=learning_rate)
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda x: lr_schedule(x))

# %%
def sdf_reg_loss(sdf, all_edges):
    sdf_f1x6x2 = sdf[all_edges.reshape(-1)].reshape(-1,2)
    mask = torch.sign(sdf_f1x6x2[...,0]) != torch.sign(sdf_f1x6x2[...,1])
    sdf_f1x6x2 = sdf_f1x6x2[mask]
    sdf_diff = torch.nn.functional.binary_cross_entropy_with_logits(sdf_f1x6x2[...,0], (sdf_f1x6x2[...,1] > 0).float()) + \
            torch.nn.functional.binary_cross_entropy_with_logits(sdf_f1x6x2[...,1], (sdf_f1x6x2[...,0] > 0).float())
    return sdf_diff

# %%
for it in tqdm.tqdm(range(iter)): 
    optimizer.zero_grad()
    if it % 10 == 0:
        tetras = tetrahedralize(grid_vertices)

    # sample random camera poses
    cameras = render.get_random_camera_batch(batch, iter_res=train_res, device=device)
    
    # render gt mesh at sampled views
    target = render.render_mesh(glctx, gt_mesh, cameras, train_res, return_types = ["mask", "depth", "normals", "colors"])

    # mesh extraction
    mc_vertices, mc_faces, mc_colors = marching_tetrahedra(grid_vertices, tetras, sdf, colors=grid_colors)
    
    if mc_vertices.shape[0] == 0:
        continue
    
    extracted_mesh = kal.rep.SurfaceMesh(vertices=mc_vertices, faces=mc_faces.int(), vertex_colors=mc_colors)
    buffers = render.render_mesh(glctx, extracted_mesh, cameras, train_res, return_types = ["mask", "depth", "normals", "colors"])

    # reconstruction loss
    mask_loss = (buffers['mask'] - target['mask']).abs().mean() # mask loss
    depth_loss = (((((buffers['depth'] - (target['depth'])) * target['mask'])**2).sum(-1)+1e-8)).sqrt().mean() * 10 # depth loss

    normal_loss = (((((buffers['normals'] - target['normals']) * target['mask'])**2).sum(-1)+1e-8)).sqrt().mean() * 1.0
    edges = get_edges(tetras)
    reg_sdf_loss = sdf_reg_loss(sdf, edges.reshape(-1, 2)).mean() * 0.1
    color_loss = (((((buffers['colors'] - target['colors']) * target['mask'])**2).sum(-1)+1e-8)).sqrt().mean() * 1.0
    total_loss = mask_loss + depth_loss + normal_loss + color_loss + reg_sdf_loss
    total_loss.backward()
    optimizer.step()
    scheduler.step()
    
    if (it + 1) % 100 == 0: # save intermediate results every 100 iters
        tqdm.tqdm.write(f"Iter {it+1}/{iter}, Mask Loss: {mask_loss.item():.4f}, Depth Loss: {depth_loss.item():.4f}, Normal Loss: {normal_loss.item():.4f}, Reg SDF Loss: {reg_sdf_loss.item():.4f}, Color Loss: {color_loss.item():.4f}, Total Loss: {total_loss.item():.4f}")
# Out:
#  10%|▉         | 99/1000 [00:20<01:55,  7.77it/s]
# Iter 100/1000, Mask Loss: 0.0058, Depth Loss: 0.0711, Normal Loss: 0.1244, Reg SDF Loss: 0.1557, Color Loss: 0.0245, Total Loss: 0.3814
#  20%|█▉        | 199/1000 [00:41<01:42,  7.80it/s]
# Iter 200/1000, Mask Loss: 0.0042, Depth Loss: 0.0558, Normal Loss: 0.0983, Reg SDF Loss: 0.1548, Color Loss: 0.0095, Total Loss: 0.3226
#  30%|██▉       | 299/1000 [01:02<01:31,  7.68it/s]
# Iter 300/1000, Mask Loss: 0.0046, Depth Loss: 0.1035, Normal Loss: 0.1245, Reg SDF Loss: 0.1545, Color Loss: 0.0141, Total Loss: 0.4013
#  40%|███▉      | 399/1000 [01:23<01:17,  7.78it/s]
# Iter 400/1000, Mask Loss: 0.0043, Depth Loss: 0.0552, Normal Loss: 0.0954, Reg SDF Loss: 0.1545, Color Loss: 0.0068, Total Loss: 0.3162
#  50%|████▉     | 499/1000 [01:43<01:04,  7.71it/s]
# Iter 500/1000, Mask Loss: 0.0058, Depth Loss: 0.0601, Normal Loss: 0.1180, Reg SDF Loss: 0.1542, Color Loss: 0.0073, Total Loss: 0.3453
#  60%|█████▉    | 599/1000 [02:04<00:51,  7.73it/s]
# Iter 600/1000, Mask Loss: 0.0038, Depth Loss: 0.0407, Normal Loss: 0.0835, Reg SDF Loss: 0.1542, Color Loss: 0.0052, Total Loss: 0.2874
#  70%|██████▉   | 699/1000 [02:25<00:38,  7.83it/s]
# Iter 700/1000, Mask Loss: 0.0032, Depth Loss: 0.0401, Normal Loss: 0.0785, Reg SDF Loss: 0.1538, Color Loss: 0.0054, Total Loss: 0.2810
#  80%|███████▉  | 799/1000 [02:45<00:25,  7.79it/s]
# Iter 800/1000, Mask Loss: 0.0035, Depth Loss: 0.0775, Normal Loss: 0.1062, Reg SDF Loss: 0.1533, Color Loss: 0.0092, Total Loss: 0.3497
#  90%|████████▉ | 899/1000 [03:06<00:12,  7.82it/s]
# Iter 900/1000, Mask Loss: 0.0030, Depth Loss: 0.0382, Normal Loss: 0.0699, Reg SDF Loss: 0.1532, Color Loss: 0.0047, Total Loss: 0.2689
# 100%|██████████| 1000/1000 [03:26<00:00,  4.83it/s]
# Iter 1000/1000, Mask Loss: 0.0030, Depth Loss: 0.0387, Normal Loss: 0.0679, Reg SDF Loss: 0.1527, Color Loss: 0.0047, Total Loss: 0.2669

# %%
with torch.no_grad():
    mc_vertices, mc_faces, mc_colors = marching_tetrahedra(grid_vertices, tetras, sdf, colors=grid_colors)
    
final_mesh = kal.rep.SurfaceMesh(vertices=mc_vertices, faces=mc_faces)
final_mesh.vertex_colors = mc_colors
print(f"Final vertices: {mc_vertices.shape}, Final faces: {mc_faces.shape}")
# Out:
# Final vertices: torch.Size([96378, 3]), Final faces: torch.Size([196740, 3])

# %%
# Evaluate using c3d chamfer distance
pc_prime, _ = kal.ops.mesh.sample_points(final_mesh.vertices.unsqueeze(0), final_mesh.faces, num_sampling_points)
pc_prime = pc_prime.squeeze(0)

chamfer_dist = c3d.ops.chamfer_distance(pc, pc_prime, squared=True)
print(f"Chamfer Distance: {chamfer_dist.item():.6f}")
# Out:
# Chamfer Distance: 0.004393

# %%
# Render the final oriented mesh using matplotlib (PNG) to keep notebook size minimal
camera = render.get_rotate_camera(0)
output_final = render.render_mesh(glctx, final_mesh, camera, [512, 512], return_types=['colors'])
img_final = output_final['colors'][0].cpu().detach().numpy()

output_gt = render.render_mesh(glctx, gt_mesh, camera, [512, 512], return_types=['colors'])
img_gt = output_gt['colors'][0].cpu().detach().numpy()

f, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(img_final)
ax[0].set_title("Final Reconstruction")
ax[0].axis('off')

ax[1].imshow(img_gt)
ax[1].set_title("Ground Truth")
ax[1].axis('off')

plt.tight_layout()
plt.show()

# Rotate final mesh around the X-axis by 90 degrees to make Z-upward axis
angle = torch.tensor(np.pi / 2, device=device)
R_x = torch.tensor([
    [1.0, 0.0, 0.0],
    [0.0, torch.cos(angle), -torch.sin(angle)],
    [0.0, torch.sin(angle), torch.cos(angle)]
], device=device)

final_mesh.vertices = torch.matmul(final_mesh.vertices, R_x.T)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.02115321..1.084659].
